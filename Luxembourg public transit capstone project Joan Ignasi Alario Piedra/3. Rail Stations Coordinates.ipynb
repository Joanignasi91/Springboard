# %%
import pandas as pd

# %%
# Sourced from Open Street Maps we save the train station locations, node codes, and the rail lines they belong to
luxembourg_rail_coordinates = pd.DataFrame(columns=['name', 'lat', 'long', 'node', 'lines'])

# %%
luxembourg_rail_coordinates.loc[0] = ['Luxembourg Gare Centrale', 49.5999681, 6.1342493, 'Luxembourg Central Station (3964570119)', ['l10','l30','l50','l60','l70','l90']]
luxembourg_rail_coordinates.loc[1] = ['Pfaffenthal-Kirchberg', 49.6189511, 6.1329276, 'Pfaffenthal-Kirchberg (5221201562)', ['l10']]
luxembourg_rail_coordinates.loc[2] = ['Dommeldange', 49.6337994, 6.1368137, 'Dommeldange (3730497336)', ['l10']]
luxembourg_rail_coordinates.loc[3] = ['Walferdange', 49.6619472, 6.1362958, 'Walferdange (3730496871)', ['l10']]
luxembourg_rail_coordinates.loc[4] = ['Heisdorf', 49.6753985, 6.1393661, 'Heisdorf (443135663)', ['l10']]
luxembourg_rail_coordinates.loc[5] = ['Lorentzweiler', 49.6983494, 6.1402969, 'Lorentzweiler (3730496691)', ['l10']]
luxembourg_rail_coordinates.loc[6] = ['Lintgen', 49.7215823, 6.1228044, 'Lintgen (3730497337)', ['l10']]
luxembourg_rail_coordinates.loc[7] = ['Mersch', 49.7517605, 6.1104283, 'Mersch (75368914)', ['l10']]
luxembourg_rail_coordinates.loc[8] = ['Cruchten', 49.7961925, 6.1199998, 'Cruchten (3730496689)', ['l10']]
luxembourg_rail_coordinates.loc[9] = ['Colmar-Berg', 49.8151001, 6.1009530, 'Colmar-Berg (3730497335)', ['l10']]
luxembourg_rail_coordinates.loc[10] = ['Schieren', 49.8297530, 6.0953290, 'Schieren (3730496870)', ['l10']]
luxembourg_rail_coordinates.loc[11] = ['Ettelbruck', 49.8473403, 6.1065209, 'Ettelbruck (5072163539)', ['l10']]
luxembourg_rail_coordinates.loc[12] = ['Diekirch', 49.8648017, 6.1540133, 'Diekirch (1573735853)', ['l10']]
luxembourg_rail_coordinates.loc[13] = ['Michelau', 49.8966727, 6.0922668, 'Michelau (75372363)', ['l10']]
luxembourg_rail_coordinates.loc[14] = ['Goebelsmuhle', 49.9210564, 6.0534791, 'Goebelsmuhle (3728214639)', ['l10']]
luxembourg_rail_coordinates.loc[15] = ['Kautenbach', 49.9484130, 6.0223546, 'Kautenbach (3728214640)', ['l10']]
luxembourg_rail_coordinates.loc[16] = ['Merkholtz', 49.9568037, 5.9815621, 'Merkholtz (4573706201)', ['l10']]
luxembourg_rail_coordinates.loc[17] = ['Paradiso', 49.9654034, 5.9531240, 'Paradiso (5833068677)', ['l10']]
luxembourg_rail_coordinates.loc[18] = ['Wiltz', 49.9663637, 5.9270829, 'Wiltz (3727231072)', ['l10']]
luxembourg_rail_coordinates.loc[19] = ['Wilwerwiltz', 49.9883021, 6.0007319, 'Wilwerwiltz (3727997833)', ['l10']]
luxembourg_rail_coordinates.loc[20] = ['Drauffelt', 50.0168584, 6.0072032, 'Drauffelt (420756851)', ['l10']]
luxembourg_rail_coordinates.loc[21] = ['Clervaux', 50.0615608, 6.0246738, 'Clervaux (3730912911)', ['l10']]
luxembourg_rail_coordinates.loc[22] = ['Maulusmuhle', 50.0944381, 6.0259328, 'Maulusmuhle (3727997606)', ['l10']]
luxembourg_rail_coordinates.loc[23] = ['Troisvierges', 50.1193506, 5.9910136, 'Troisvierges (3727995454)', ['l10']]
luxembourg_rail_coordinates.loc[24] = ['Cents-Hamm', 49.6150126, 6.1659779, 'Cents-Hamm (25609667)', ['l30']]
luxembourg_rail_coordinates.loc[25] = ['Sandweiler-Contern', 49.5990906, 6.2117485, 'Sandweiler-Contern (1411691251)', ['l30']]
luxembourg_rail_coordinates.loc[26] = ['Oetrange', 49.6027297, 6.2580197, 'Oetrange (3725816023)', ['l30']]
luxembourg_rail_coordinates.loc[27] = ['Munsbach', 49.6303968, 6.2686170, 'Munsbach (1202059783)', ['l30']]
luxembourg_rail_coordinates.loc[28] = ['Roodt', 49.6665057, 6.3031061, 'Roodt (3725244397)', ['l30']]
luxembourg_rail_coordinates.loc[29] = ['Betzdorf', 49.6888484, 6.3486360, 'Betzdorf (5264104021)', ['l30']]
luxembourg_rail_coordinates.loc[30] = ['Wecker', 49.7000680, 6.3875875, 'Wecker (3720303904)', ['l30']]
luxembourg_rail_coordinates.loc[31] = ['Manternach', 49.7064542, 6.4232973, 'Manternach (3725242151)', ['l30']]
luxembourg_rail_coordinates.loc[32] = ['Mertert', 49.7032225, 6.4793057, 'Mertert (3725242152)', ['l30']]
luxembourg_rail_coordinates.loc[33] = ['Wasserbillig', 49.7129031, 6.4994052, 'Wasserbillig (3728754132)', ['l30']]
luxembourg_rail_coordinates.loc[34] = ['Bertrange-Strassen', 49.6129205, 6.0604258, 'Bertrange-Strassen (3734674986)', ['l50']]
luxembourg_rail_coordinates.loc[35] = ['Mamer Lycee', 49.6183823, 6.0296967, 'Mamer Lycee (3734422881)', ['l50']]
luxembourg_rail_coordinates.loc[36] = ['Mamer', 49.6257131, 6.0201719, 'Mamer (3734422882)', ['l50']]
luxembourg_rail_coordinates.loc[37] = ['Capellen', 49.6385071, 5.9823816, 'Capellen (3734423238)', ['l50']]
luxembourg_rail_coordinates.loc[38] = ['Kleinbettingen', 49.6438044, 5.9171390, 'Kleinbettingen (3734399406)', ['l50']]
luxembourg_rail_coordinates.loc[39] = ['Berchem', 49.5427666, 6.1338106, 'Berchem (3730323383)', ['l60']]
luxembourg_rail_coordinates.loc[40] = ['Bettembourg', 49.5163298, 6.1017167, 'Bettembourg (131669275)', ['l60', 'l90']]
luxembourg_rail_coordinates.loc[41] = ['Dudelange-Burange', 49.4923869, 6.0861927, 'Burange (3733314741)', ['l60']]
luxembourg_rail_coordinates.loc[42] = ['Dudelange-Ville', 49.4834215, 6.0830309, 'Dudelange-Ville (3733360829)', ['l60']]
luxembourg_rail_coordinates.loc[43] = ['Dudelange-Centre', 49.4786928, 6.0821383, 'Dudelange-Centre (3733361648)', ['l60']]
luxembourg_rail_coordinates.loc[44] = ['Dudelange-Usines', 49.4726946, 6.0793791, 'Dudelange-Usines (3733361647)', ['l60']]
luxembourg_rail_coordinates.loc[45] = ['Noertzange', 49.5080338, 6.0508470, 'Noertzange (25923526)', ['l60']]
luxembourg_rail_coordinates.loc[46] = ['Kayl', 49.4857693, 6.0352682, 'Kayl (269302083)', ['l60']]
luxembourg_rail_coordinates.loc[47] = ['Tetange', 49.4773951, 6.0349832, 'Tetange (3724529698)', ['l60']]
luxembourg_rail_coordinates.loc[48] = ['Rumelange', 49.4603105, 6.0326710, 'Rumelange (5107379363)', ['l60']]
luxembourg_rail_coordinates.loc[49] = ['Schifflange', 49.5062959, 6.0097748, 'Schifflange (3719863646)', ['l60']]
luxembourg_rail_coordinates.loc[50] = ['Esch-sur-Alzette', 49.4940890, 5.9853043, 'Esch-sur-Alzette (557580603)', ['l60']]
luxembourg_rail_coordinates.loc[51] = ['Belval-Universite', 49.4995310, 5.9462903, 'Belval-Universite (3733227187)', ['l60']]
luxembourg_rail_coordinates.loc[52] = ['Belval-Redange', 49.5030979, 5.9236701, 'Belval-Redange (3727608556)', ['l60']]
luxembourg_rail_coordinates.loc[53] = ['Belvaux-Soleuvre', 49.5151574, 5.9259002, 'Belvaux-Soleuvre (3733227188)', ['l60']]
luxembourg_rail_coordinates.loc[54] = ['Oberkorn', 49.5107334, 5.8909346, 'Oberkorn (3737370912)', ['l60']]
luxembourg_rail_coordinates.loc[55] = ['Differdange', 49.5225300, 5.8915895, 'Differdange (3727342905)', ['l60']]
luxembourg_rail_coordinates.loc[56] = ['Niederkorn', 49.5369053, 5.8940808, 'Niederkorn (2361763094)', ['l60']]
luxembourg_rail_coordinates.loc[57] = ['Petange', 49.5543344, 5.8796536, 'Petange (3721698933)', ['l60','l70']]
luxembourg_rail_coordinates.loc[58] = ['Lamadelaine', 49.5534157, 5.8608746, 'Lamadelaine (3719706037)', ['l60','l70']]
luxembourg_rail_coordinates.loc[59] = ['Rodange', 49.5510868, 5.8434629, 'Rodange (704409331)', ['l60','l70']]
luxembourg_rail_coordinates.loc[60] = ['Hollerich', 49.5956369, 6.1200199, 'Hollerich (3736255004)', ['l70']]
luxembourg_rail_coordinates.loc[61] = ['Leudelange', 49.5870299, 6.0590174, 'Leudelange (3721698138)', ['l70']]
luxembourg_rail_coordinates.loc[62] = ['Dippach-Reckange', 49.5725401, 5.9951440, 'Dippach-Reckange (3721698137)', ['l70']]
luxembourg_rail_coordinates.loc[63] = ['Schouweiler', 49.5735838, 5.9602532, 'Schouweiler (3721698934)', ['l70']]
luxembourg_rail_coordinates.loc[64] = ['Bascharage-Sanem', 49.5584333, 5.9246001, 'Bascharage-Sanem (2361763085)', ['l70']]

# %%
luxembourg_rail_coordinates
# Out:
#                         name        lat      long  \
# 0   Luxembourg Gare Centrale  49.599968  6.134249
# 1      Pfaffenthal-Kirchberg  49.618951  6.132928
# 2                Dommeldange  49.633799  6.136814
# 3                Walferdange  49.661947  6.136296
# 4                   Heisdorf  49.675399  6.139366
# 5              Lorentzweiler  49.698349  6.140297
# 6                    Lintgen  49.721582  6.122804
# 7                     Mersch  49.751761  6.110428
# 8                   Cruchten  49.796192  6.120000
# 9                Colmar-Berg  49.815100  6.100953
# 10                  Schieren  49.829753  6.095329
# 11                Ettelbruck  49.847340  6.106521
# 12                  Diekirch  49.864802  6.154013
# 13                  Michelau  49.896673  6.092267
# 14              Goebelsmuhle  49.921056  6.053479
# 15                Kautenbach  49.948413  6.022355
# 16                 Merkholtz  49.956804  5.981562
# 17                  Paradiso  49.965403  5.953124
# ...

# %%
luxembourg_rail_coordinates.to_csv('Data\luxembourg_rail_coordinates.csv',index='name')
